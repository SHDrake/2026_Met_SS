# %% [markdown]
# # 2026 Met SS — Metabolomics Analysis
#
# Notebook for metabolomics analysis.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

pd.set_option("display.max_columns", 100)
sns.set_theme(context="notebook", style="whitegrid")

# %% [markdown]
# ## Load data

# %%
DATA_DIR = Path("data")
# df = pd.read_csv(DATA_DIR / "peaks.csv")
# df.head()

# %% [markdown]
# ## Exploration

# %% [markdown]
# ## QC

# %% [markdown]
# ## Analysis
